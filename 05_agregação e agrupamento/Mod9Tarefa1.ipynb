# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv('SINASC_RO_2019.csv')
sinasc_raw.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %% [markdown]
# # Tarefa 1

# %% [markdown]
# ### 1. Idade media das mães e dos pais por município (coluna munResNome)

# %%
media_idades = sinasc_raw.groupby('munResNome').agg({'IDADEMAE': 'mean', 'IDADEPAI': 'mean'})

media_idades = media_idades.round(2)

media_idades
# Out:
#                            IDADEMAE  IDADEPAI
# munResNome
# Alta Floresta D'Oeste         25.99     29.55
# Alto Alegre dos Parecis       24.84     29.18
# Alto Paraíso                  24.96     28.83
# Alvorada D'Oeste              25.77     30.76
# Ariquemes                     25.61     32.47
# Buritis                       25.56     30.81
# Cabixi                        26.04     34.33
# Cacaulândia                   25.55     36.33
# Cacoal                        26.89     30.93
# Campo Novo de Rondônia        24.83     30.50
# Candeias do Jamari            25.24     29.89
# Castanheiras                  27.28     30.39
# Cerejeiras                    27.24     31.65
# Chupinguaia                   25.33     29.63
# Colorado do Oeste             27.60     34.35
# Corumbiara                    24.72     32.47
# Costa Marques                 24.41     30.61
# Cujubim                       24.48     31.40
# Espigão D'Oeste               26.09     31.20
# ...

# %% [markdown]
# ### 2. Peso médio dos bebes por sexo que nasceram no dia do seu aniversário por faixas de escolaridade mae
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
sinasc_raw['DTNASC'] = pd.to_datetime(sinasc_raw['DTNASC'])


data_selecionada = sinasc_raw[sinasc_raw['DTNASC'].dt.month == 10]
data_selecionada = data_selecionada[data_selecionada['DTNASC'].dt.day == 29]


peso_medio_por_sexo_escolaridade = data_selecionada.groupby(['ESCMAE', 'SEXO']).agg({'PESO': 'mean'})

peso_medio_por_sexo_escolaridade
# Out:
#                                   PESO
# ESCMAE          SEXO
# 12 anos ou mais Feminino   3398.400000
#                 Masculino  3478.384615
# 4 a 7 anos      Feminino   3216.666667
#                 Masculino  3388.000000
# 8 a 11 anos     Feminino   3120.000000
#                 Masculino  3285.272727

# %% [markdown]
# ### 3. Qual o municipio que nasceu menos bebe em 2019?
#     - qual a idade media, maxima, minima das maes nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
nascimentos_por_municipio = sinasc_raw.groupby('munResNome').size()

municipios_ordenados = nascimentos_por_municipio.sort_values()

menor_municipio = municipios_ordenados.index[1]  # foi pego o valor do index 1 por conta de 
                                                    # o valor do index 0 não representar nenhum municipipo
    
menor_municipio = sinasc_raw[sinasc_raw['munResNome'] == menor_municipio]

menor_municipio = sinasc_raw[sinasc_raw['munResNome'] == segundo_menor_municipio]

menor_municipio = menor_municipio[['IDADEMAE', 'IDADEPAI']].agg({
    'IDADEMAE': ['mean', 'max', 'min'],
    'IDADEPAI': ['mean', 'max', 'min']
})

menor_municipio
# Out:
#       IDADEMAE   IDADEPAI
# mean  27.28125  30.392857
# max   39.00000  43.000000
# min   17.00000  17.000000

# %% [markdown]
# ### 4. Qual o municipio que nasceu mais bebe no mês de março?
#     - qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
nascimentos_marco = sinasc_raw[sinasc_raw['DTNASC'].dt.month == 3]

nascimentos_por_municipio_marco = nascimentos_marco.groupby('munResNome').size()

municipio_mais_nascimentos = nascimentos_por_municipio_marco.idxmax()

maior_municipio_marco = sinasc_raw[sinasc_raw['munResNome'] == municipio_mais_nascimentos]

estatisticas_filhos_vivos = maior_municipio_marco['QTDFILVIVO'].agg(['mean', 'max', 'min'])

estatisticas_idade_pais = maior_municipio_marco[['IDADEPAI', 'IDADEMAE']].agg(['mean', 'max', 'min'])

estatisticas_df = pd.DataFrame({
    'Quantidade de filhos vivos': [estatisticas_filhos_vivos['mean'], estatisticas_filhos_vivos['max'], estatisticas_filhos_vivos['min']],
    'Idade dos pais (média)': [estatisticas_idade_pais.loc['mean', 'IDADEPAI'], estatisticas_idade_pais.loc['max', 'IDADEPAI'], estatisticas_idade_pais.loc['min', 'IDADEPAI']],
    'Idade das mães (média)': [estatisticas_idade_pais.loc['mean', 'IDADEMAE'], estatisticas_idade_pais.loc['max', 'IDADEMAE'], estatisticas_idade_pais.loc['min', 'IDADEMAE']]
}, index=['Média', 'Máxima', 'Mínima'])

estatisticas_df
# Out:
#         Quantidade de filhos vivos  Idade dos pais (média)  \
# Média                     1.167236               32.352679
# Máxima                   12.000000               65.000000
# Mínima                    0.000000               16.000000
#
#         Idade das mães (média)
# Média                 26.31267
# Máxima                47.00000
# Mínima                12.00000

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados. Algo que você julgue relevante e novo pra você.

# %% [markdown]
# - Os dados nos mostram que o risco de um bebê não nascer vivo é maior quando falamos de pais mais jovens

# %%
sinasc_raw.dtypes
# Out:
# ORIGEM          int64
# CODESTAB      float64
# CODMUNNASC      int64
# LOCNASC         int64
# IDADEMAE        int64
#                ...
# munResUf       object
# munResLat     float64
# munResLon     float64
# munResAlt     float64
# munResArea    float64
# Length: 69, dtype: object

# %%
sinasc_raw.select_dtypes(exclude=['int64','float64'])
# Out:
#                 ESCMAE         GESTACAO GRAVIDEZ    PARTO      DTNASC  \
# 0          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-19
# 1          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-21
# 2          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-25
# 3      12 anos ou mais  37 a 41 semanas    Única  Cesáreo  2019-03-20
# 4          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-03-23
# ...                ...              ...      ...      ...         ...
# 27023  12 anos ou mais  32 a 36 semanas    Única  Cesáreo  2019-12-13
# 27024      8 a 11 anos  37 a 41 semanas    Única  Vaginal  2019-10-04
# 27025      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-08-02
# 27026      8 a 11 anos  32 a 36 semanas    Única  Vaginal  2019-12-23
# 27027      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-12-27
#
#             SEXO RACACOR  DTCADASTRO CODANOMAL VERSAOSIST   DTRECEBIM  \
# ...

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
# ...
